# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/avajeong/miniforge3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/avajeong/miniforge3/lib/python3.12/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/avajeong/miniforge3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/avajeong/miniforge3/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/avajeong/miniforge3/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/avajeong/miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DataFrames

# %%
poke_card = pd.read_csv('data/pokecard.csv')
poke_card
# Out:
#                            cardCount                       name  \
# 0    {'total': 102, 'official': 102}                   Base Set
# 1      {'total': 64, 'official': 64}                     Jungle
# 2      {'total': 53, 'official': 53}  Wizards Black Star Promos
# 3        {'total': 7, 'official': 7}              W Promotional
# 4      {'total': 62, 'official': 62}                     Fossil
# ..                               ...                        ...
# 160  {'total': 246, 'official': 189}            Astral Radiance
# 161    {'total': 88, 'official': 78}                 Pokémon GO
# 162  {'total': 247, 'official': 196}                Lost Origin
# 163  {'total': 245, 'official': 195}             Silver Tempest
# 164  {'total': 230, 'official': 159}               Crown Zenith
#
#                                                 symbol  \
# 0                                                  NaN
# 1     https://assets.tcgdex.net/univ/base/base2/symbol
# 2     https://assets.tcgdex.net/univ/base/basep/symbol
# 3                                                  NaN
# 4     https://assets.tcgdex.net/univ/base/base3/symbol
# ..                                                 ...
# 160  https://assets.tcgdex.net/univ/swsh/swsh10/symbol
# 161  https://assets.tcgdex.net/univ/swsh/swsh10.5/s...
# 162  https://assets.tcgdex.net/univ/swsh/swsh11/symbol
# 163                                                NaN
# 164                                                NaN
#
#                                                 logo        id
# 0       https://assets.tcgdex.net/en/base/base1/logo     base1
# 1       https://assets.tcgdex.net/en/base/base2/logo     base2
# 2       https://assets.tcgdex.net/en/base/basep/logo     basep
# 3                                                NaN        wp
# 4       https://assets.tcgdex.net/en/base/base3/logo     base3
# ..                                               ...       ...
# 160    https://assets.tcgdex.net/en/swsh/swsh10/logo    swsh10
# 161  https://assets.tcgdex.net/en/swsh/swsh10.5/logo  swsh10.5
# 162    https://assets.tcgdex.net/en/swsh/swsh11/logo    swsh11
# 163    https://assets.tcgdex.net/en/swsh/swsh12/logo    swsh12
# 164  https://assets.tcgdex.net/en/swsh/swsh12.5/logo  swsh12.5
#
# [165 rows x 5 columns]

# %%
mod_card_feb = pd.read_csv('data/modern_pkmn_cards_feb2025.csv')
mod_card_feb
# Out:
#            ID           Name  Pokedex Number Supertype           Subtypes  \
# 0     swsh1-1       Celebi V           251.0   Pokémon           Basic, V
# 1     swsh1-2        Roselia           315.0   Pokémon              Basic
# 2     swsh1-3        Roselia           315.0   Pokémon              Basic
# 3     swsh1-4       Roserade           407.0   Pokémon            Stage 1
# 4     swsh1-5       Cottonee           546.0   Pokémon              Basic
# ...       ...            ...             ...       ...                ...
# 6340  svp-161   Charizard ex             6.0   Pokémon        Stage 2, ex
# 6341  svp-162  Houndstone ex           972.0   Pokémon        Stage 1, ex
# 6342  svp-163   Cinderace ex           815.0   Pokémon  Stage 2, Tera, ex
# 6343  svp-164      Lapras ex           131.0   Pokémon    Basic, Tera, ex
# 6344  svp-165   Terapagos ex          1024.0   Pokémon    Basic, Tera, ex
#
#          HP      Types                                   Attacks   Weaknesses  \
# 0     180.0      Grass        Find a Friend (), Line Force (50+)      Fire ×2
# 1      70.0      Grass                               Absorb (10)      Fire ×2
# 2      70.0      Grass                Sweet Scent (), Sting (20)      Fire ×2
# 3     120.0      Grass     Paralyze Poison (30), Mega Drain (90)      Fire ×2
# 4      60.0      Grass                               Attach (10)      Fire ×2
# ...     ...        ...                                       ...          ...
# 6340  330.0       Fire  Brave Wing (60+), Explosive Vortex (330)     Water ×2
# 6341  260.0    Psychic                    Horrifying Fang (100+)  Darkness ×2
# 6342  320.0       Fire      Flare Strike (280), Garnet Volley ()     Water ×2
# 6343  220.0      Water       Power Splash (40×), Larimar Rain ()     Metal ×2
# 6344  230.0  Colorless  Unified Beatdown (30×), Crown Opal (180)  Fighting ×2
#
#       Retreat Cost  ... TCG Price Date TCG Market Price USD (Normal)  \
# 0                1  ...     2025/02/22                           NaN
# 1                1  ...     2025/02/22                          0.07
# 2                1  ...     2025/02/22                          0.05
# 3                1  ...     2025/02/22                          0.18
# 4                1  ...     2025/02/22                          0.06
# ...            ...  ...            ...                           ...
# 6340             2  ...     2025/02/22                           NaN
# 6341             3  ...     2025/02/22                           NaN
# 6342             0  ...            NaN                           NaN
# 6343             2  ...            NaN                           NaN
# 6344             2  ...            NaN                           NaN
#
#      TCG Low Price USD (Normal) TCG High Price USD (Normal)  \
# 0                           NaN                         NaN
# 1                          0.01                        1.31
# 2                          0.01                        1.31
# 3                          0.03                        2.00
# 4                          0.01                        5.01
# ...                         ...                         ...
# 6340                        NaN                         NaN
# 6341                        NaN                         NaN
# 6342                        NaN                         NaN
# 6343                        NaN                         NaN
# 6344                        NaN                         NaN
#
#      TCG Market Price USD (Reverse Holofoil)  \
# 0                                        NaN
# 1                                       0.20
# 2                                       0.20
# 3                                       0.49
# 4                                       0.20
# ...                                      ...
# 6340                                     NaN
# 6341                                     NaN
# 6342                                     NaN
# 6343                                     NaN
# 6344                                     NaN
#
#      TCG Low Price USD (Reverse Holofoil)  \
# 0                                     NaN
# 1                                    0.05
# 2                                    0.05
# 3                                    0.24
# 4                                    0.06
# ...                                   ...
# 6340                                  NaN
# 6341                                  NaN
# 6342                                  NaN
# 6343                                  NaN
# 6344                                  NaN
#
#      TCG High Price USD (Reverse Holofoil) TCG Market Price USD (Holofoil)  \
# 0                                      NaN                            0.83
# 1                                     2.00                             NaN
# 2                                     1.14                             NaN
# 3                                     4.99                             NaN
# 4                                     2.00                             NaN
# ...                                    ...                             ...
# 6340                                   NaN                            4.39
# 6341                                   NaN                            0.88
# 6342                                   NaN                             NaN
# 6343                                   NaN                             NaN
# 6344                                   NaN                             NaN
#
#       TCG Low Price USD (Holofoil)  TCG High Price USD (Holofoil)
# 0                             0.49                           7.99
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 6340                          3.00                          30.00
# 6341                          0.59                           3.87
# 6342                           NaN                            NaN
# 6343                           NaN                            NaN
# 6344                           NaN                            NaN
#
# [6345 rows x 27 columns]

# %%
mod_card_march = pd.read_csv('data/modern_pkmn_cards_mar2025.csv')
mod_card_march
# Out:
#            ID           Name  Pokedex Number Supertype           Subtypes  \
# 0     swsh1-1       Celebi V           251.0   Pokémon           Basic, V
# 1     swsh1-3        Roselia           315.0   Pokémon              Basic
# 2     swsh1-2        Roselia           315.0   Pokémon              Basic
# 3     swsh1-5       Cottonee           546.0   Pokémon              Basic
# 4     swsh1-4       Roserade           407.0   Pokémon            Stage 1
# ...       ...            ...             ...       ...                ...
# 6340  svp-161   Charizard ex             6.0   Pokémon        Stage 2, ex
# 6341  svp-162  Houndstone ex           972.0   Pokémon        Stage 1, ex
# 6342  svp-164      Lapras ex           131.0   Pokémon    Basic, Tera, ex
# 6343  svp-163   Cinderace ex           815.0   Pokémon  Stage 2, Tera, ex
# 6344  svp-165   Terapagos ex          1024.0   Pokémon    Basic, Tera, ex
#
#          HP      Types                                   Attacks   Weaknesses  \
# 0     180.0      Grass        Find a Friend (), Line Force (50+)      Fire ×2
# 1      70.0      Grass                Sweet Scent (), Sting (20)      Fire ×2
# 2      70.0      Grass                               Absorb (10)      Fire ×2
# 3      60.0      Grass                               Attach (10)      Fire ×2
# 4     120.0      Grass     Paralyze Poison (30), Mega Drain (90)      Fire ×2
# ...     ...        ...                                       ...          ...
# 6340  330.0       Fire  Brave Wing (60+), Explosive Vortex (330)     Water ×2
# 6341  260.0    Psychic                    Horrifying Fang (100+)  Darkness ×2
# 6342  220.0      Water       Power Splash (40×), Larimar Rain ()     Metal ×2
# 6343  320.0       Fire      Flare Strike (280), Garnet Volley ()     Water ×2
# 6344  230.0  Colorless  Unified Beatdown (30×), Crown Opal (180)  Fighting ×2
#
#       Retreat Cost  ... TCG Price Date TCG Market Price USD (Normal)  \
# 0                1  ...     2025/03/01                           NaN
# 1                1  ...     2025/03/01                          0.05
# 2                1  ...     2025/03/01                          0.06
# 3                1  ...     2025/03/01                          0.06
# 4                1  ...     2025/03/01                          0.19
# ...            ...  ...            ...                           ...
# 6340             2  ...     2025/03/01                           NaN
# 6341             3  ...     2025/03/01                           NaN
# 6342             2  ...            NaN                           NaN
# 6343             0  ...            NaN                           NaN
# 6344             2  ...            NaN                           NaN
#
#      TCG Low Price USD (Normal) TCG High Price USD (Normal)  \
# 0                           NaN                         NaN
# 1                          0.01                        1.99
# 2                          0.01                        1.99
# 3                          0.01                        5.01
# 4                          0.03                        2.00
# ...                         ...                         ...
# 6340                        NaN                         NaN
# 6341                        NaN                         NaN
# 6342                        NaN                         NaN
# 6343                        NaN                         NaN
# 6344                        NaN                         NaN
#
#      TCG Market Price USD (Reverse Holofoil)  \
# 0                                        NaN
# 1                                       0.20
# 2                                       0.20
# 3                                       0.20
# 4                                       0.49
# ...                                      ...
# 6340                                     NaN
# 6341                                     NaN
# 6342                                     NaN
# 6343                                     NaN
# 6344                                     NaN
#
#      TCG Low Price USD (Reverse Holofoil)  \
# 0                                     NaN
# 1                                    0.05
# 2                                    0.05
# 3                                    0.06
# 4                                    0.24
# ...                                   ...
# 6340                                  NaN
# 6341                                  NaN
# 6342                                  NaN
# 6343                                  NaN
# 6344                                  NaN
#
#      TCG High Price USD (Reverse Holofoil) TCG Market Price USD (Holofoil)  \
# 0                                      NaN                            0.93
# 1                                     1.14                             NaN
# 2                                     2.00                             NaN
# 3                                     2.00                             NaN
# 4                                     4.99                             NaN
# ...                                    ...                             ...
# 6340                                   NaN                            4.74
# 6341                                   NaN                            0.98
# 6342                                   NaN                             NaN
# 6343                                   NaN                             NaN
# 6344                                   NaN                             NaN
#
#       TCG Low Price USD (Holofoil)  TCG High Price USD (Holofoil)
# 0                             0.49                           7.99
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 6340                          3.00                          30.00
# 6341                          0.45                           7.95
# 6342                           NaN                            NaN
# 6343                           NaN                            NaN
# 6344                           NaN                            NaN
#
# [6345 rows x 27 columns]

# %%
vin_card_march = pd.read_csv('data/vintage_pkmn_cards_mar2025.csv')
vin_card_march
# Out:
#            ID              Name  Pokedex Number Supertype Subtypes     HP  \
# 0     base1-1          Alakazam            65.0   Pokémon  Stage 2   80.0
# 1     base1-4         Charizard             6.0   Pokémon  Stage 2  120.0
# 2     base1-5          Clefairy            35.0   Pokémon    Basic   40.0
# 3     base1-2         Blastoise             9.0   Pokémon  Stage 2  100.0
# 4     base1-3           Chansey           113.0   Pokémon    Basic  120.0
# ..        ...               ...             ...       ...      ...    ...
# 863  gym2-127   Fighting Energy             NaN    Energy    Basic    NaN
# 864  gym2-128       Fire Energy             NaN    Energy    Basic    NaN
# 865  gym2-130  Lightning Energy             NaN    Energy    Basic    NaN
# 866  gym2-132      Water Energy             NaN    Energy    Basic    NaN
# 867  gym2-131    Psychic Energy             NaN    Energy    Basic    NaN
#
#          Types                       Attacks    Weaknesses  Retreat Cost  ...  \
# 0      Psychic              Confuse Ray (30)    Psychic ×2             3  ...
# 1         Fire               Fire Spin (100)      Water ×2             3  ...
# 2    Colorless         Sing (), Metronome ()   Fighting ×2             1  ...
# 3        Water              Hydro Pump (40+)  Lightning ×2             3  ...
# 4    Colorless  Scrunch (), Double-edge (80)   Fighting ×2             1  ...
# ..         ...                           ...           ...           ...  ...
# 863        NaN                           NaN           NaN             0  ...
# 864        NaN                           NaN           NaN             0  ...
# 865        NaN                           NaN           NaN             0  ...
# 866        NaN                           NaN           NaN             0  ...
# 867        NaN                           NaN           NaN             0  ...
#
#     TCG Price Date TCG Market Price USD (Normal) TCG Low Price USD (Normal)  \
# 0       2025/03/01                           NaN                        NaN
# 1       2025/03/01                           NaN                        NaN
# 2       2025/03/01                           NaN                        NaN
# 3       2025/03/01                           NaN                        NaN
# 4       2025/03/01                           NaN                        NaN
# ..             ...                           ...                        ...
# 863     2025/03/01                           NaN                        NaN
# 864     2025/03/01                           NaN                        NaN
# 865     2025/03/01                           NaN                        NaN
# 866     2025/03/01                           NaN                        NaN
# 867     2025/03/01                           NaN                        NaN
#
#     TCG High Price USD (Normal) TCG Market Price USD (Reverse Holofoil)  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# ..                          ...                                     ...
# 863                         NaN                                     NaN
# 864                         NaN                                     NaN
# 865                         NaN                                     NaN
# 866                         NaN                                     NaN
# 867                         NaN                                     NaN
#
#     TCG Low Price USD (Reverse Holofoil)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 863                                  NaN
# 864                                  NaN
# 865                                  NaN
# 866                                  NaN
# 867                                  NaN
#
#     TCG High Price USD (Reverse Holofoil) TCG Market Price USD (Holofoil)  \
# 0                                     NaN                           66.69
# 1                                     NaN                          398.63
# 2                                     NaN                           27.62
# 3                                     NaN                          169.56
# 4                                     NaN                           38.21
# ..                                    ...                             ...
# 863                                   NaN                             NaN
# 864                                   NaN                             NaN
# 865                                   NaN                             NaN
# 866                                   NaN                             NaN
# 867                                   NaN                             NaN
#
#      TCG Low Price USD (Holofoil)  TCG High Price USD (Holofoil)
# 0                           32.19                         149.99
# 1                          330.00                        1249.99
# 2                           15.00                          47.99
# 3                          100.25                         238.68
# 4                           15.59                          74.98
# ..                            ...                            ...
# 863                           NaN                            NaN
# 864                           NaN                            NaN
# 865                           NaN                            NaN
# 866                           NaN                            NaN
# 867                           NaN                            NaN
#
# [868 rows x 27 columns]

# %%
vin_card_feb = pd.read_csv('data/vintage_pkmn_cards_feb2025.csv')
vin_card_feb
# Out:
#            ID              Name  Pokedex Number Supertype Subtypes     HP  \
# 0     base1-1          Alakazam            65.0   Pokémon  Stage 2   80.0
# 1     base1-2         Blastoise             9.0   Pokémon  Stage 2  100.0
# 2     base1-3           Chansey           113.0   Pokémon    Basic  120.0
# 3     base1-4         Charizard             6.0   Pokémon  Stage 2  120.0
# 4     base1-5          Clefairy            35.0   Pokémon    Basic   40.0
# ..        ...               ...             ...       ...      ...    ...
# 863  gym2-128       Fire Energy             NaN    Energy    Basic    NaN
# 864  gym2-129      Grass Energy             NaN    Energy    Basic    NaN
# 865  gym2-130  Lightning Energy             NaN    Energy    Basic    NaN
# 866  gym2-131    Psychic Energy             NaN    Energy    Basic    NaN
# 867  gym2-132      Water Energy             NaN    Energy    Basic    NaN
#
#          Types                       Attacks    Weaknesses  Retreat Cost  ...  \
# 0      Psychic              Confuse Ray (30)    Psychic ×2             3  ...
# 1        Water              Hydro Pump (40+)  Lightning ×2             3  ...
# 2    Colorless  Scrunch (), Double-edge (80)   Fighting ×2             1  ...
# 3         Fire               Fire Spin (100)      Water ×2             3  ...
# 4    Colorless         Sing (), Metronome ()   Fighting ×2             1  ...
# ..         ...                           ...           ...           ...  ...
# 863        NaN                           NaN           NaN             0  ...
# 864        NaN                           NaN           NaN             0  ...
# 865        NaN                           NaN           NaN             0  ...
# 866        NaN                           NaN           NaN             0  ...
# 867        NaN                           NaN           NaN             0  ...
#
#     TCG Price Date TCG Market Price USD (Normal) TCG Low Price USD (Normal)  \
# 0       2025/02/22                           NaN                        NaN
# 1       2025/02/22                           NaN                        NaN
# 2       2025/02/22                           NaN                        NaN
# 3       2025/02/22                           NaN                        NaN
# 4       2025/02/22                           NaN                        NaN
# ..             ...                           ...                        ...
# 863     2025/02/22                           NaN                        NaN
# 864     2025/02/22                           NaN                        NaN
# 865     2025/02/22                           NaN                        NaN
# 866     2025/02/22                           NaN                        NaN
# 867     2025/02/22                           NaN                        NaN
#
#     TCG High Price USD (Normal) TCG Market Price USD (Reverse Holofoil)  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# ..                          ...                                     ...
# 863                         NaN                                     NaN
# 864                         NaN                                     NaN
# 865                         NaN                                     NaN
# 866                         NaN                                     NaN
# 867                         NaN                                     NaN
#
#     TCG Low Price USD (Reverse Holofoil)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 863                                  NaN
# 864                                  NaN
# 865                                  NaN
# 866                                  NaN
# 867                                  NaN
#
#     TCG High Price USD (Reverse Holofoil) TCG Market Price USD (Holofoil)  \
# 0                                     NaN                           66.05
# 1                                     NaN                          168.56
# 2                                     NaN                           37.92
# 3                                     NaN                          446.45
# 4                                     NaN                           27.67
# ..                                    ...                             ...
# 863                                   NaN                             NaN
# 864                                   NaN                             NaN
# 865                                   NaN                             NaN
# 866                                   NaN                             NaN
# 867                                   NaN                             NaN
#
#      TCG Low Price USD (Holofoil)  TCG High Price USD (Holofoil)
# 0                           34.25                         149.99
# 1                          100.00                         235.22
# 2                           15.59                          74.98
# 3                          285.00                        1249.99
# 4                           15.00                          47.99
# ..                            ...                            ...
# 863                           NaN                            NaN
# 864                           NaN                            NaN
# 865                           NaN                            NaN
# 866                           NaN                            NaN
# 867                           NaN                            NaN
#
# [868 rows x 27 columns]
